# %% [markdown]
# ![Linear.png](data:image/png;base64,...)

# %% [markdown]
# - A função ReLU é eficaz para redes profundas e ajudou a alcançar melhores resultados, com boas diferenças para as outras funções de ativação
# - Regularização L1 reduz o risco de overfitting e ajuda a simplificar o modelo.
# - A quantidade de neurônios também ajuda a diminuir o risco de overfitting.
# - O modelo, pelos resultados, está equilibrado e simples. Seria possível mudar as configurações para obter resultados melhores porém aumentaria a chance de overfitting.
